# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
import random
sns.set()

# %%
import pkg_resources
import types


def get_imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            name = val.__name__.split('.')[0]
        elif isinstance(val, type):
            name = val.__module__.split('.')[0]
        poorly_named_packages = {'PIL': 'Pillow', 'sklearn': 'scikit-learn'}
        if name in poorly_named_packages.keys():
            name = poorly_named_packages[name]
        yield name


imports = list(set(get_imports()))
requirements = []
for m in pkg_resources.working_set:
    if m.project_name in imports and m.project_name != 'pip':
        requirements.append((m.project_name, m.version))

for r in requirements:
    print('{}=={}'.format(*r))
# Out:
# seaborn==0.13.0
# pandas==2.0.3
# numpy==1.23.1
# matplotlib==3.5.3

# %%
df = pd.read_csv('ATVI_all.csv')
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volumn
# 0  2021/10/18  76.139999  76.720001  75.239998  75.137978  75.137978  5417407
# 1  2021/10/19  76.769997  77.199997  75.949997  75.905098  75.905098  4238549
# 2  2021/10/20  77.519997  78.080002  77.081001  76.790230  76.790230  4537908
# 3  2021/10/21  77.720001  78.739998  76.720100  77.399986  77.399986  5904311
# 4  2021/10/22  78.620003  80.919998  78.620003  77.960564  77.960564  6960407

# %%
class Deep_Evolution_Strategy:

    inputs = None

    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights

    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / (np.std(rewards) + 1e-7)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')


class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.randn(input_size, layer_size),
            np.random.randn(layer_size, output_size),
            np.random.randn(1, layer_size),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-1]
        decision = np.dot(feed, self.weights[1])
        return decision

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

# %%
class Agent:

    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(self, model, window_size, trend, skip, initial_money):
        self.model = model
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        self.es = Deep_Evolution_Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )

    def act(self, sequence):
        decision = self.model.predict(np.array(sequence))
        return np.argmax(decision[0])
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def get_reward(self, weights):
        initial_money = self.initial_money
        starting_money = initial_money
        self.model.weights = weights
        state = self.get_state(0)
        inventory = []
        quantity = 0
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                starting_money -= close[t]
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                starting_money += self.trend[t]

            state = next_state
        return ((starting_money - initial_money) / initial_money) * 100

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self.initial_money
        state = self.get_state(0)
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            state = next_state

        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest

# %%
close = df.Close.values.tolist()
window_size = 30
skip = 1
initial_money = 100000

model = Model(input_size = window_size, layer_size = 500, output_size = 3)
agent = Agent(model = model, 
              window_size = window_size,
              trend = close,
              skip = skip,
              initial_money = initial_money)
agent.fit(iterations = 500, checkpoint = 10)
# Out:
# iter 10. reward: 0.390958
# iter 20. reward: 0.335530
# iter 30. reward: 0.518631
# iter 40. reward: 0.562127
# iter 50. reward: 0.561292
# iter 60. reward: 0.681684
# iter 70. reward: 0.637289
# iter 80. reward: 0.695606
# iter 90. reward: 0.736912
# iter 100. reward: 0.825755
# iter 110. reward: 0.796149
# iter 120. reward: 0.868191
# iter 130. reward: 1.051173
# iter 140. reward: 0.963285
# iter 150. reward: 0.989805
# iter 160. reward: 0.934974
# iter 170. reward: 1.043127
# iter 180. reward: 1.180548
# iter 190. reward: 1.294711
# iter 200. reward: 1.108853
# iter 210. reward: 1.409802
# iter 220. reward: 0.913438
# iter 230. reward: 1.321281
# iter 240. reward: 1.323371
# iter 250. reward: 1.312932
# iter 260. reward: 1.347219
# iter 270. reward: 1.407758
# iter 280. reward: 1.412361
# iter 290. reward: 1.363524
# iter 300. reward: 1.504709
# iter 310. reward: 1.366948
# iter 320. reward: 1.405585
# iter 330. reward: 1.417484
# iter 340. reward: 1.572895
# iter 350. reward: 1.287213
# iter 360. reward: 1.348774
# iter 370. reward: 1.317706
# iter 380. reward: 1.376504
# iter 390. reward: 1.318024
# iter 400. reward: 1.321973
# iter 410. reward: 0.541412
# iter 420. reward: 1.542363
# iter 430. reward: 1.626667
# iter 440. reward: 1.457161
# iter 450. reward: 1.649384
# iter 460. reward: 1.312644
# iter 470. reward: 1.600312
# iter 480. reward: 1.483044
# iter 490. reward: 1.369472
# iter 500. reward: 1.625582
# time taken to train: 207.45530486106873 seconds

# %%
states_buy, states_sell, total_gains, invest = agent.buy()
# Out:
# day 9: buy 1 unit at price 76.898415, total balance 99923.101585
# day 10: buy 1 unit at price 78.039246, total balance 99845.062340
# day 11, sell 1 unit at price 76.387001, investment -0.665051 %, total balance 99921.449341,
# day 12: buy 1 unit at price 65.647385, total balance 99855.801956
# day 13: buy 1 unit at price 67.102943, total balance 99788.699013
# day 14: buy 1 unit at price 66.709549, total balance 99721.989464
# day 15: buy 1 unit at price 65.716225, total balance 99656.273239
# day 16: buy 1 unit at price 65.991600, total balance 99590.281639
# day 18: buy 1 unit at price 66.384995, total balance 99523.896645
# day 21: buy 1 unit at price 65.047462, total balance 99458.849182
# day 23: buy 1 unit at price 61.634777, total balance 99397.214405
# day 24: buy 1 unit at price 61.349571, total balance 99335.864834
# day 25: buy 1 unit at price 61.172543, total balance 99274.692291
# day 26: buy 1 unit at price 60.749645, total balance 99213.942646
# day 27: buy 1 unit at price 59.903851, total balance 99154.038795
# day 28, sell 1 unit at price 59.618645, investment -23.604279 %, total balance 99213.657440,
# day 29: buy 1 unit at price 59.313766, total balance 99154.343674
# day 30: buy 1 unit at price 57.632011, total balance 99096.711662
# day 31: buy 1 unit at price 56.333813, total balance 99040.377850
# day 32: buy 1 unit at price 56.343651, total balance 98984.034199
# day 33: buy 1 unit at price 56.412495, total balance 98927.621704
# day 34: buy 1 unit at price 57.130436, total balance 98870.491268
# day 35: buy 1 unit at price 57.799202, total balance 98812.692066
# day 37: buy 1 unit at price 58.094250, total balance 98754.597816
# day 38: buy 1 unit at price 57.632011, total balance 98696.965805
# day 39: buy 1 unit at price 57.730362, total balance 98639.235443
# day 40: buy 1 unit at price 58.536816, total balance 98580.698627
# day 41: buy 1 unit at price 59.264587, total balance 98521.434040
# day 42: buy 1 unit at price 60.474274, total balance 98460.959766
# day 43: buy 1 unit at price 60.346420, total balance 98400.613346
# day 44: buy 1 unit at price 60.779152, total balance 98339.834194
# day 45: buy 1 unit at price 62.539581, total balance 98277.294613
# day 46: buy 1 unit at price 63.041157, total balance 98214.253456
# day 47: buy 1 unit at price 64.083656, total balance 98150.169800
# day 48: buy 1 unit at price 64.368858, total balance 98085.800941
# day 49: buy 1 unit at price 65.568703, total balance 98020.232239
# day 50: buy 1 unit at price 66.050621, total balance 97954.181618
# day 51: buy 1 unit at price 66.375160, total balance 97887.806458
# day 52: buy 1 unit at price 65.431023, total balance 97822.375435
# day 53: buy 1 unit at price 66.306313, total balance 97756.069122
# day 54, sell 1 unit at price 66.089951, investment 0.674156 %, total balance 97822.159073,
# day 55, sell 1 unit at price 65.194977, investment -2.843343 %, total balance 97887.354050,
# day 56: buy 1 unit at price 62.765785, total balance 97824.588264
# day 57: buy 1 unit at price 62.982151, total balance 97761.606113
# day 58: buy 1 unit at price 62.067513, total balance 97699.538601
# day 63, sell 1 unit at price 80.950356, investment 21.347478 %, total balance 97780.488956,
# day 64, sell 1 unit at price 80.792999, investment 22.942241 %, total balance 97861.281956,
# day 66, sell 1 unit at price 80.006210, investment 21.236961 %, total balance 97941.288166,
# day 67, sell 1 unit at price 78.649010, investment 18.474077 %, total balance 98019.937176,
# day 69, sell 1 unit at price 77.478668, investment 19.110977 %, total balance 98097.415844,
# day 70: buy 1 unit at price 77.596687, total balance 98019.819157
# day 71, sell 1 unit at price 77.832718, investment 26.280521 %, total balance 98097.651875,
# day 72, sell 1 unit at price 77.704872, investment 26.659193 %, total balance 98175.356747,
# day 73, sell 1 unit at price 77.754036, investment 27.106105 %, total balance 98253.110783,
# day 74, sell 1 unit at price 77.940903, investment 28.298531 %, total balance 98331.051685,
# day 76, sell 1 unit at price 77.940903, investment 30.110005 %, total balance 98408.992588,
# day 81, sell 1 unit at price 80.153732, investment 35.135125 %, total balance 98489.146320,
# day 84, sell 1 unit at price 80.114395, investment 39.010236 %, total balance 98569.260715,
# day 85, sell 1 unit at price 79.632492, investment 41.358250 %, total balance 98648.893208,
# day 86, sell 1 unit at price 79.711174, investment 41.473215 %, total balance 98728.604382,
# day 87, sell 1 unit at price 79.888199, investment 41.614370 %, total balance 98808.492580,
# day 88, sell 1 unit at price 79.376785, investment 38.939576 %, total balance 98887.869366,
# day 90, sell 1 unit at price 80.094734, investment 38.574118 %, total balance 98967.964100,
# day 91, sell 1 unit at price 80.153732, investment 37.971886 %, total balance 99048.117832,
# day 92, sell 1 unit at price 79.543968, investment 38.020462 %, total balance 99127.661800,
# day 93: buy 1 unit at price 80.134071, total balance 99047.527729
# day 94: buy 1 unit at price 80.153732, total balance 98967.373997
# day 97, sell 1 unit at price 79.691498, investment 38.040877 %, total balance 99047.065495,
# day 98, sell 1 unit at price 79.494804, investment 35.803090 %, total balance 99126.560299,
# day 100, sell 1 unit at price 78.983391, investment 33.272489 %, total balance 99205.543690,
# day 101, sell 1 unit at price 78.235954, investment 29.370639 %, total balance 99283.779644,
# day 102, sell 1 unit at price 78.196609, investment 29.579533 %, total balance 99361.976254,
# day 103, sell 1 unit at price 77.813057, investment 28.025901 %, total balance 99439.789310,
# day 104, sell 1 unit at price 77.586853, investment 24.060397 %, total balance 99517.376163,
# day 105: buy 1 unit at price 77.458992, total balance 99439.917171
# day 106: buy 1 unit at price 77.537666, total balance 99362.379505
# day 108, sell 1 unit at price 77.763870, investment 23.354130 %, total balance 99440.143375,
# day 110: buy 1 unit at price 78.285118, total balance 99361.858257
# day 111, sell 1 unit at price 78.688347, investment 22.790039 %, total balance 99440.546604,
# day 112, sell 1 unit at price 79.416122, investment 23.376621 %, total balance 99519.962727,
# day 113: buy 1 unit at price 79.032562, total balance 99440.930164
# day 114: buy 1 unit at price 78.786697, total balance 99362.143467
# day 115, sell 1 unit at price 79.484970, investment 21.223948 %, total balance 99441.628437,
# day 116, sell 1 unit at price 79.396461, investment 20.205473 %, total balance 99521.024899,
# day 117: buy 1 unit at price 79.052238, total balance 99441.972660
# day 118: buy 1 unit at price 78.786697, total balance 99363.185963
# day 119: buy 1 unit at price 78.786697, total balance 99284.399265
# day 120: buy 1 unit at price 78.767021, total balance 99205.632244
# day 121: buy 1 unit at price 78.167107, total balance 99127.465137
# day 122: buy 1 unit at price 78.226112, total balance 99049.239025
# day 123: buy 1 unit at price 78.255791, total balance 98970.983234
# day 124: buy 1 unit at price 78.087608, total balance 98892.895626
# day 126: buy 1 unit at price 78.186539, total balance 98814.709087
# day 127: buy 1 unit at price 78.067825, total balance 98736.641262
# day 130: buy 1 unit at price 77.217003, total balance 98659.424259
# day 131: buy 1 unit at price 76.237556, total balance 98583.186703
# day 132: buy 1 unit at price 75.287804, total balance 98507.898899
# day 133: buy 1 unit at price 75.881401, total balance 98432.017498
# day 134: buy 1 unit at price 74.793144, total balance 98357.224354
# day 135: buy 1 unit at price 77.226891, total balance 98279.997463
# day 136, sell 1 unit at price 77.939201, investment 17.422242 %, total balance 98357.936665,
# day 137, sell 1 unit at price 78.394295, investment 19.812119 %, total balance 98436.330959,
# day 138, sell 1 unit at price 77.919418, investment 17.514329 %, total balance 98514.250378,
# day 139, sell 1 unit at price 77.009232, investment 22.693011 %, total balance 98591.259609,
# day 140: buy 1 unit at price 76.346390, total balance 98514.913219
# day 141: buy 1 unit at price 76.099052, total balance 98438.814167
# day 142: buy 1 unit at price 76.643188, total balance 98362.170979
# day 143: buy 1 unit at price 76.554146, total balance 98285.616833
# day 144: buy 1 unit at price 76.910301, total balance 98208.706532
# day 145: buy 1 unit at price 77.167534, total balance 98131.538998
# day 146, sell 1 unit at price 77.701767, investment 23.371091 %, total balance 98209.240765,
# day 147, sell 1 unit at price 77.088379, investment 24.200851 %, total balance 98286.329144,
# day 148: buy 1 unit at price 76.910301, total balance 98209.418842
# day 149: buy 1 unit at price 76.573936, total balance 98132.844906
# day 150: buy 1 unit at price 76.376068, total balance 98056.468838
# day 152: buy 1 unit at price 76.880623, total balance 97979.588215
# day 153: buy 1 unit at price 77.157639, total balance 97902.430576
# day 154: buy 1 unit at price 77.365395, total balance 97825.065182
# day 155, sell 1 unit at price 77.048805, investment -0.706064 %, total balance 97902.113987,
# day 156, sell 1 unit at price 76.583832, investment -4.430375 %, total balance 97978.697819,
# day 157: buy 1 unit at price 77.395081, total balance 97901.302738
# day 158, sell 1 unit at price 77.058701, investment -3.861369 %, total balance 97978.361439,
# day 159: buy 1 unit at price 76.959770, total balance 97901.401669
# day 160, sell 1 unit at price 77.197212, investment -0.337959 %, total balance 97978.598881,
# day 163, sell 1 unit at price 75.663757, investment -2.416772 %, total balance 98054.262638,
# day 164: buy 1 unit at price 73.962112, total balance 97980.300526
# day 165: buy 1 unit at price 73.843391, total balance 97906.457134
# day 166: buy 1 unit at price 74.545815, total balance 97831.911320
# day 167: buy 1 unit at price 73.140968, total balance 97758.770351
# day 168: buy 1 unit at price 73.912643, total balance 97684.857708
# day 169, sell 1 unit at price 75.238342, investment -3.891897 %, total balance 97760.096050,
# day 170: buy 1 unit at price 74.892075, total balance 97685.203976
# day 173: buy 1 unit at price 77.177429, total balance 97608.026546
# day 175, sell 1 unit at price 77.127953, investment -2.409905 %, total balance 97685.154499,
# day 176: buy 1 unit at price 77.029022, total balance 97608.125477
# day 177, sell 1 unit at price 77.731445, investment -1.339378 %, total balance 97685.856922,
# day 178, sell 1 unit at price 78.028244, investment -1.295339 %, total balance 97763.885166,
# day 179, sell 1 unit at price 77.533585, investment -1.590513 %, total balance 97841.418751,
# day 180, sell 1 unit at price 77.771019, investment -1.289150 %, total balance 97919.189770,
# day 181, sell 1 unit at price 77.296143, investment -1.867379 %, total balance 97996.485912,
# day 182: buy 1 unit at price 76.959770, total balance 97919.526142
# day 183: buy 1 unit at price 75.723114, total balance 97843.803028
# day 184: buy 1 unit at price 75.149300, total balance 97768.653728
# day 185: buy 1 unit at price 75.426315, total balance 97693.227413
# day 187: buy 1 unit at price 76.168304, total balance 97617.059109
# day 190, sell 1 unit at price 78.641624, investment 0.607056 %, total balance 97695.700733,
# day 193, sell 1 unit at price 78.611946, investment 0.493229 %, total balance 97774.312679,
# day 194, sell 1 unit at price 78.938431, investment 0.872319 %, total balance 97853.251110,
# day 195, sell 1 unit at price 78.661415, investment 0.734824 %, total balance 97931.912525,
# day 196, sell 1 unit at price 79.096718, investment 1.164112 %, total balance 98011.009243,
# day 197, sell 1 unit at price 79.225334, investment 1.482696 %, total balance 98090.234577,
# day 198, sell 1 unit at price 78.473442, investment 1.627154 %, total balance 98168.708019,
# day 199, sell 1 unit at price 79.729881, investment 4.580846 %, total balance 98248.437901,
# day 200, sell 1 unit at price 79.799141, investment 5.992122 %, total balance 98328.237041,
# day 201, sell 1 unit at price 79.630951, investment 4.941329 %, total balance 98407.867992,
# day 203, sell 1 unit at price 79.729881, investment 6.600521 %, total balance 98487.597874,
# day 204: buy 1 unit at price 80.046478, total balance 98407.551395
# day 207, sell 1 unit at price 79.868401, investment 3.420454 %, total balance 98487.419796,
# day 209, sell 1 unit at price 79.670525, investment 4.354017 %, total balance 98567.090321,
# day 210, sell 1 unit at price 79.581490, investment 4.576190 %, total balance 98646.671810,
# day 211, sell 1 unit at price 79.413300, investment 3.614295 %, total balance 98726.085110,
# day 212, sell 1 unit at price 78.908745, investment 3.075730 %, total balance 98804.993855,
# day 213, sell 1 unit at price 78.493225, investment 2.058143 %, total balance 98883.487080,
# day 214, sell 1 unit at price 78.433868, investment 1.641020 %, total balance 98961.920948,
# day 217, sell 1 unit at price 77.909523, investment 1.299204 %, total balance 99039.830471,
# day 218: buy 1 unit at price 77.780914, total balance 98962.049557
# day 221: buy 1 unit at price 76.702545, total balance 98885.347012
# day 223: buy 1 unit at price 76.890518, total balance 98808.456493
# day 224: buy 1 unit at price 76.564041, total balance 98731.892452
# day 225: buy 1 unit at price 77.672089, total balance 98654.220364
# day 226, sell 1 unit at price 77.296143, investment 0.943149 %, total balance 98731.516506,
# day 227: buy 1 unit at price 75.940765, total balance 98655.575741
# day 228: buy 1 unit at price 75.782471, total balance 98579.793270
# day 229: buy 1 unit at price 76.010017, total balance 98503.783253
# day 230: buy 1 unit at price 75.208656, total balance 98428.574596
# day 231: buy 1 unit at price 75.129517, total balance 98353.445080
# day 232: buy 1 unit at price 74.239120, total balance 98279.205959
# day 233: buy 1 unit at price 74.516136, total balance 98204.689823
# day 234: buy 1 unit at price 76.207878, total balance 98128.481945
# day 235: buy 1 unit at price 74.150078, total balance 98054.331867
# day 236: buy 1 unit at price 73.536697, total balance 97980.795170
# day 237: buy 1 unit at price 74.061043, total balance 97906.734127
# day 238: buy 1 unit at price 74.585388, total balance 97832.148739
# day 239: buy 1 unit at price 74.070938, total balance 97758.077801
# day 240: buy 1 unit at price 73.546585, total balance 97684.531216
# day 241: buy 1 unit at price 73.566376, total balance 97610.964840
# day 242: buy 1 unit at price 74.199547, total balance 97536.765293
# day 244: buy 1 unit at price 73.042038, total balance 97463.723255
# day 245: buy 1 unit at price 72.567154, total balance 97391.156101
# day 246: buy 1 unit at price 72.962891, total balance 97318.193211
# day 247: buy 1 unit at price 72.765030, total balance 97245.428181
# day 248: buy 1 unit at price 72.715561, total balance 97172.712620
# day 249: buy 1 unit at price 72.339615, total balance 97100.373005
# day 250: buy 1 unit at price 71.360176, total balance 97029.012829
# day 251: buy 1 unit at price 70.994133, total balance 96958.018696
# day 252: buy 1 unit at price 71.488792, total balance 96886.529903
# day 253: buy 1 unit at price 71.439323, total balance 96815.090580
# day 254: buy 1 unit at price 72.527580, total balance 96742.563000
# day 255: buy 1 unit at price 71.933990, total balance 96670.629009
# day 256: buy 1 unit at price 71.736122, total balance 96598.892887
# day 257: buy 1 unit at price 71.726227, total balance 96527.166660
# day 258: buy 1 unit at price 71.706444, total balance 96455.460217
# day 259: buy 1 unit at price 71.726227, total balance 96383.733990
# day 260: buy 1 unit at price 72.072495, total balance 96311.661495
# day 261: buy 1 unit at price 72.023033, total balance 96239.638462
# day 262: buy 1 unit at price 72.527580, total balance 96167.110882
# day 263: buy 1 unit at price 71.884529, total balance 96095.226353
# day 264: buy 1 unit at price 71.132637, total balance 96024.093716
# day 265: buy 1 unit at price 71.191994, total balance 95952.901722
# day 266: buy 1 unit at price 70.341171, total balance 95882.560551
# day 267: buy 1 unit at price 71.231567, total balance 95811.328983
# day 268: buy 1 unit at price 70.895195, total balance 95740.433788
# day 269: buy 1 unit at price 72.834282, total balance 95667.599506
# day 270: buy 1 unit at price 73.348724, total balance 95594.250782
# day 271, sell 1 unit at price 73.170647, investment -4.196892 %, total balance 95667.421429,
# day 273, sell 1 unit at price 73.556480, investment -4.323771 %, total balance 95740.977909,
# day 275: buy 1 unit at price 73.309151, total balance 95667.668758
# day 276: buy 1 unit at price 74.001686, total balance 95593.667072
# day 277: buy 1 unit at price 75.070152, total balance 95518.596920
# day 278, sell 1 unit at price 75.772575, investment -1.795108 %, total balance 95594.369495,
# day 279, sell 1 unit at price 72.685883, investment -6.048585 %, total balance 95667.055378,
# day 280, sell 1 unit at price 73.922539, investment -4.486773 %, total balance 95740.977917,
# day 281, sell 1 unit at price 73.546585, investment -4.435025 %, total balance 95814.524502,
# day 282: buy 1 unit at price 73.160751, total balance 95741.363750
# day 283, sell 1 unit at price 74.387520, investment 0.575169 %, total balance 95815.751270,
# day 284, sell 1 unit at price 74.951439, investment 1.500537 %, total balance 95890.702709,
# day 288: buy 1 unit at price 73.962112, total balance 95816.740597
# day 290, sell 1 unit at price 76.534363, investment 2.667552 %, total balance 95893.274960,
# day 291, sell 1 unit at price 75.911087, investment 3.787369 %, total balance 95969.186047,
# day 293, sell 1 unit at price 75.554932, investment 2.221931 %, total balance 96044.740978,
# day 294, sell 1 unit at price 75.268021, investment 0.501984 %, total balance 96120.008999,
# day 295, sell 1 unit at price 75.178978, investment -2.589424 %, total balance 96195.187977,
# day 297: buy 1 unit at price 75.080048, total balance 96120.107929
# day 298, sell 1 unit at price 74.892075, investment -2.774211 %, total balance 96195.000004,
# day 299, sell 1 unit at price 75.139404, investment -2.365347 %, total balance 96270.139408,
# day 300: buy 1 unit at price 74.981117, total balance 96195.158291
# day 302, sell 1 unit at price 75.940765, investment 0.287431 %, total balance 96271.099056,
# day 304, sell 1 unit at price 76.059479, investment 1.211161 %, total balance 96347.158535,
# day 305, sell 1 unit at price 76.019905, investment 0.786980 %, total balance 96423.178440,
# day 307, sell 1 unit at price 76.761902, investment 0.779323 %, total balance 96499.940342,
# day 308, sell 1 unit at price 76.395859, investment -4.560625 %, total balance 96576.336201,
# day 309, sell 1 unit at price 76.860840, investment -1.182905 %, total balance 96653.197041,
# day 311, sell 1 unit at price 76.079269, investment -0.812588 %, total balance 96729.276310,
# day 312, sell 1 unit at price 75.841835, investment -1.363865 %, total balance 96805.118145,
# day 313: buy 1 unit at price 73.764244, total balance 96731.353901
# day 314: buy 1 unit at price 73.685104, total balance 96657.668797
# day 315: buy 1 unit at price 72.972786, total balance 96584.696011
# day 316: buy 1 unit at price 73.051926, total balance 96511.644085
# day 317: buy 1 unit at price 74.417198, total balance 96437.226887
# day 319: buy 1 unit at price 73.843391, total balance 96363.383495
# day 322: buy 1 unit at price 75.149300, total balance 96288.234196
# day 324, sell 1 unit at price 75.881401, investment -0.891594 %, total balance 96364.115597,
# day 325, sell 1 unit at price 76.287033, investment -1.783209 %, total balance 96440.402630,
# day 326, sell 1 unit at price 74.436981, investment -1.980207 %, total balance 96514.839611,
# day 327: buy 1 unit at price 70.816048, total balance 96444.023563
# day 328: buy 1 unit at price 74.793144, total balance 96369.230419
# day 329, sell 1 unit at price 72.112068, investment -4.843340 %, total balance 96441.342487,
# day 330: buy 1 unit at price 74.456772, total balance 96366.885715
# day 331, sell 1 unit at price 74.644745, investment -1.796174 %, total balance 96441.530460,
# day 332, sell 1 unit at price 75.772575, investment 0.749806 %, total balance 96517.303036,
# day 333: buy 1 unit at price 75.960548, total balance 96441.342487
# day 335: buy 1 unit at price 76.682762, total balance 96364.659725
# day 336: buy 1 unit at price 76.742119, total balance 96287.917606
# day 338: buy 1 unit at price 76.296928, total balance 96211.620678
# day 339, sell 1 unit at price 76.247452, investment 1.488011 %, total balance 96287.868130,
# day 340: buy 1 unit at price 76.000122, total balance 96211.868008
# day 341: buy 1 unit at price 75.920975, total balance 96135.947033
# day 342, sell 1 unit at price 75.436211, investment 1.612479 %, total balance 96211.383244,
# day 343, sell 1 unit at price 74.911865, investment 0.531065 %, total balance 96286.295109,
# day 345, sell 1 unit at price 78.542694, investment 3.063746 %, total balance 96364.837803,
# day 346, sell 1 unit at price 78.780128, investment 6.244162 %, total balance 96443.617931,
# day 347: buy 1 unit at price 78.414085, total balance 96365.203846
# day 349: buy 1 unit at price 77.533585, total balance 96287.670261
# day 352: buy 1 unit at price 78.245895, total balance 96209.424366
# day 353, sell 1 unit at price 78.414085, investment 6.632590 %, total balance 96287.838451,
# day 355, sell 1 unit at price 78.146965, investment 5.516966 %, total balance 96365.985416,
# day 356, sell 1 unit at price 78.493225, investment 5.239414 %, total balance 96444.478642,
# day 357, sell 1 unit at price 78.898849, investment 6.517956 %, total balance 96523.377491,
# day 358, sell 1 unit at price 77.800697, investment 5.784242 %, total balance 96601.178188,
# day 359, sell 1 unit at price 78.829597, investment 7.154385 %, total balance 96680.007786,
# day 362, sell 1 unit at price 83.449760, investment 12.466671 %, total balance 96763.457546,
# day 363, sell 1 unit at price 83.637733, investment 14.506298 %, total balance 96847.095280,
# day 364, sell 1 unit at price 83.983994, investment 15.732792 %, total balance 96931.079273,
# day 365, sell 1 unit at price 84.676521, investment 16.054231 %, total balance 97015.755795,
# day 366, sell 1 unit at price 84.419304, investment 16.016312 %, total balance 97100.175098,
# day 367: buy 1 unit at price 84.201645, total balance 97015.973454
# day 368, sell 1 unit at price 84.468765, investment 16.163259 %, total balance 97100.442219,
# day 369, sell 1 unit at price 84.310478, investment 16.548144 %, total balance 97184.752697,
# day 370, sell 1 unit at price 84.567703, investment 18.508260 %, total balance 97269.320400,
# day 371, sell 1 unit at price 84.181854, investment 18.575790 %, total balance 97353.502254,
# day 372, sell 1 unit at price 84.043350, investment 17.561575 %, total balance 97437.545605,
# day 373, sell 1 unit at price 84.666634, investment 18.515447 %, total balance 97522.212238,
# day 374, sell 1 unit at price 84.359940, investment 16.314289 %, total balance 97606.572178,
# day 375, sell 1 unit at price 84.587486, investment 17.590427 %, total balance 97691.159664,
# day 378, sell 1 unit at price 84.656738, investment 18.011311 %, total balance 97775.816402,
# day 381, sell 1 unit at price 85.814247, investment 19.641379 %, total balance 97861.630650,
# day 382, sell 1 unit at price 75.990227, investment 5.974056 %, total balance 97937.620876,
# day 383: buy 1 unit at price 76.781693, total balance 97860.839184
# day 384: buy 1 unit at price 76.880623, total balance 97783.958561
# day 385: buy 1 unit at price 76.603615, total balance 97707.354946
# day 387, sell 1 unit at price 74.427094, investment 3.765522 %, total balance 97781.782040,
# day 388: buy 1 unit at price 73.793922, total balance 97707.988117
# day 391: buy 1 unit at price 74.704109, total balance 97633.284008
# day 394: buy 1 unit at price 76.544258, total balance 97556.739750
# day 396: buy 1 unit at price 76.949875, total balance 97479.789875
# day 397: buy 1 unit at price 77.058701, total balance 97402.731174
# day 398, sell 1 unit at price 77.355507, investment 7.330137 %, total balance 97480.086681,
# day 399: buy 1 unit at price 77.751228, total balance 97402.335453
# day 400: buy 1 unit at price 78.216217, total balance 97324.119236
# day 401: buy 1 unit at price 78.285469, total balance 97245.833767
# day 402: buy 1 unit at price 76.979553, total balance 97168.854214
# day 403: buy 1 unit at price 76.316711, total balance 97092.537502
# day 404: buy 1 unit at price 77.820488, total balance 97014.717014
# day 405: buy 1 unit at price 79.165970, total balance 96935.551044
# day 407: buy 1 unit at price 79.344048, total balance 96856.206997
# day 408: buy 1 unit at price 79.640846, total balance 96776.566151
# day 410: buy 1 unit at price 80.016792, total balance 96696.549358
# day 411: buy 1 unit at price 79.640846, total balance 96616.908512
# day 412: buy 1 unit at price 79.165970, total balance 96537.742542
# day 413, sell 1 unit at price 79.522125, investment 10.412075 %, total balance 96617.264668,
# day 414, sell 1 unit at price 78.918633, investment 8.811892 %, total balance 96696.183300,
# day 416, sell 1 unit at price 80.363060, investment 11.794653 %, total balance 96776.546360,
# day 417, sell 1 unit at price 80.580704, investment 13.282323 %, total balance 96857.127064,
# day 418, sell 1 unit at price 81.095161, investment 13.910508 %, total balance 96938.222225,
# day 419, sell 1 unit at price 81.016014, investment 15.175810 %, total balance 97019.238239,
# day 422, sell 1 unit at price 81.025909, investment 13.750002 %, total balance 97100.264149,
# day 423, sell 1 unit at price 82.509903, investment 16.382927 %, total balance 97182.774052,
# day 426, sell 1 unit at price 82.193314, investment 12.849762 %, total balance 97264.967365,
# day 427, sell 1 unit at price 83.400299, investment 13.703817 %, total balance 97348.367664,
# day 428, sell 1 unit at price 82.450531, investment 12.469631 %, total balance 97430.818195,
# day 429, sell 1 unit at price 81.985558, investment 10.788770 %, total balance 97512.803753,
# day 430, sell 1 unit at price 81.817368, investment 8.987880 %, total balance 97594.621120,
# day 431, sell 1 unit at price 81.550247, investment 11.467208 %, total balance 97676.171368,
# day 432, sell 1 unit at price 81.817368, investment 10.620647 %, total balance 97757.988735,
# day 433, sell 1 unit at price 90.018890, investment 19.897221 %, total balance 97848.007626,
# day 434, sell 1 unit at price 89.039459, investment 18.749176 %, total balance 97937.047085,
# day 435, sell 1 unit at price 88.584366, investment 20.091200 %, total balance 98025.631451,
# day 436, sell 1 unit at price 89.108711, investment 20.931784 %, total balance 98114.740162,
# day 437, sell 1 unit at price 92.215195, investment 26.369294 %, total balance 98206.955357,
# day 438, sell 1 unit at price 91.750214, investment 25.595886 %, total balance 98298.705570,
# day 440: buy 1 unit at price 91.305016, total balance 98207.400555
# day 441, sell 1 unit at price 90.929077, investment 22.188257 %, total balance 98298.329632,
# day 442, sell 1 unit at price 91.562248, investment 23.995183 %, total balance 98389.891880,
# day 443, sell 1 unit at price 91.740326, investment 22.077420 %, total balance 98481.632206,
# day 444, sell 1 unit at price 91.680962, investment 29.463539 %, total balance 98573.313168,
# day 445, sell 1 unit at price 91.156616, investment 21.878305 %, total balance 98664.469784,
# day 446, sell 1 unit at price 91.542458, investment 22.947121 %, total balance 98756.012241,
# day 448, sell 1 unit at price 91.889999, investment 20.970690 %, total balance 98847.902241,
# day 451, sell 1 unit at price 91.580002, investment 19.427104 %, total balance 98939.482243,
# day 454, sell 1 unit at price 91.440002, investment 19.152304 %, total balance 99030.922245,
# day 455, sell 1 unit at price 91.419998, investment 19.821335 %, total balance 99122.342243,
# day 456, sell 1 unit at price 91.209999, investment 20.012964 %, total balance 99213.552242,
# day 457, sell 1 unit at price 90.790001, investment 19.584873 %, total balance 99304.342243,
# day 458, sell 1 unit at price 90.910004, investment 15.935808 %, total balance 99395.252247,
# day 460, sell 1 unit at price 90.430000, investment 16.633328 %, total balance 99485.682247,
# day 461, sell 1 unit at price 90.470001, investment 15.622680 %, total balance 99576.152248,
# day 462, sell 1 unit at price 90.720001, investment 7.741365 %, total balance 99666.872250,
# day 464, sell 1 unit at price 91.739998, investment 19.481604 %, total balance 99758.612247,
# day 465, sell 1 unit at price 91.410004, investment 18.898625 %, total balance 99850.022251,
# day 466, sell 1 unit at price 91.660004, investment 19.654933 %, total balance 99941.682255,
# day 467, sell 1 unit at price 91.769997, investment 24.359830 %, total balance 100033.452251,
# day 469, sell 1 unit at price 91.980003, investment 23.125762 %, total balance 100125.432255,
# day 470: buy 1 unit at price 91.989998, total balance 100033.442257
# day 471, sell 1 unit at price 92.040001, investment 20.244161 %, total balance 100125.482258,
# day 472, sell 1 unit at price 92.029999, investment 19.597334 %, total balance 100217.512257,
# day 473, sell 1 unit at price 92.070000, investment 19.480343 %, total balance 100309.582256,
# day 474: buy 1 unit at price 92.010002, total balance 100217.572254
# day 475, sell 1 unit at price 92.120003, investment 18.480447 %, total balance 100309.692257,
# day 476, sell 1 unit at price 92.180000, investment 17.852798 %, total balance 100401.872257,
# day 477, sell 1 unit at price 92.129997, investment 17.684672 %, total balance 100494.002254,
# day 478: buy 1 unit at price 92.269997, total balance 100401.732258
# day 479: buy 1 unit at price 92.220001, total balance 100309.512257
# day 480: buy 1 unit at price 91.820000, total balance 100217.692257
# day 481, sell 1 unit at price 91.910004, investment 19.395346 %, total balance 100309.602261,
# day 482: buy 1 unit at price 92.070000, total balance 100217.532261
# day 484, sell 1 unit at price 92.349998, investment 21.008881 %, total balance 100309.882259,
# day 485, sell 1 unit at price 93.919998, investment 20.688010 %, total balance 100403.802258,
# day 486, sell 1 unit at price 94.050003, investment 18.801050 %, total balance 100497.852261,
# day 487, sell 1 unit at price 94.000000, investment 18.471395 %, total balance 100591.852261,
# day 488, sell 1 unit at price 93.919998, investment 17.929433 %, total balance 100685.772259,
# day 489, sell 1 unit at price 93.540001, investment 16.900463 %, total balance 100779.312260,
# day 490, sell 1 unit at price 93.629997, investment 17.565297 %, total balance 100872.942257,
# day 491, sell 1 unit at price 93.940002, investment 18.662100 %, total balance 100966.882259,
# day 492, sell 1 unit at price 93.889999, investment 2.831152 %, total balance 101060.772259,
# day 493, sell 1 unit at price 93.750000, investment 1.913254 %, total balance 101154.522259,
# day 494, sell 1 unit at price 93.669998, investment 1.804147 %, total balance 101248.192257,
# day 495, sell 1 unit at price 94.239998, investment 2.135040 %, total balance 101342.432255,
# day 496, sell 1 unit at price 94.339996, investment 2.298845 %, total balance 101436.772251,
# day 497, sell 1 unit at price 94.339996, investment 2.744496 %, total balance 101531.112247,
# day 498, sell 1 unit at price 94.470001, investment 2.606714 %, total balance 101625.582249,

# %%
fig = plt.figure(figsize = (10, 6))
plt.style.use('seaborn-white')
plt.plot(close, label='price')
plt.plot(close, '^', markersize=10, color='g', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='r', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.xlabel('days')
plt.ylabel('price')
plt.legend()
plt.show()
